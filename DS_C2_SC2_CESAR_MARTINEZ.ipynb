# %%
import numpy as np
import pandas as pd

# %%
#a
vacunacion = pd.read_csv('/content/country_vaccinations.csv')
vacunacion.head(3)
# Out:
#        country iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG  2021-02-24                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN              1367.0
# 2                      NaN                     NaN              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                             0.0                            0.0
# 1                             NaN                            NaN
# 2                             NaN                            NaN
#
#    people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# ...

# %%
#b
vacunacion['date']=pd.to_datetime(vacunacion['date'])
vacunacion.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86512 entries, 0 to 86511
# Data columns (total 15 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   country                              86512 non-null  object
#  1   iso_code                             86512 non-null  object
#  2   date                                 86512 non-null  datetime64[ns]
#  3   total_vaccinations                   43607 non-null  float64
#  4   people_vaccinated                    41294 non-null  float64
#  5   people_fully_vaccinated              38802 non-null  float64
#  6   daily_vaccinations_raw               35362 non-null  float64
#  7   daily_vaccinations                   86213 non-null  float64
#  8   total_vaccinations_per_hundred       43607 non-null  float64
#  9   people_vaccinated_per_hundred        41294 non-null  float64
#  10  people_fully_vaccinated_per_hundred  38802 non-null  float64
# ...

# %%
#c

df_newVac= vacunacion.copy()
df_newVac['newVac'] = df_newVac['vaccines'].str.split(', ').str.len()
df_newVac['newVac']
# Out:
# 0        4
# 1        4
# 2        4
# 3        4
# 4        4
#         ..
# 86507    4
# 86508    4
# 86509    4
# 86510    4
# 86511    4
# Name: newVac, Length: 86512, dtype: int64

# %%
#d

total_vacapl = vacunacion['daily_vaccinations'].sum()

print("La suma total de vacunas aplicadas en el mundo es de :",total_vacapl)
# Out:
# La suma total de vacunas aplicadas en el mundo es de : 11320239871.0

# %%
#e
vacunacion[['country','daily_vaccinations']].groupby('country').mean()
# Out:
#                    daily_vaccinations
# country
# Afghanistan              14610.681934
# Albania                   6276.210046
# Algeria                  33904.356436
# Andorra                    367.716019
# Angola                   44821.457584
# ...                               ...
# Wales                    15518.411765
# Wallis and Futuna           33.886486
# Yemen                     2556.115756
# Zambia                    9649.805158
# Zimbabwe                 21669.066832
#
# [223 rows x 1 columns]

# %%
#f

vaccines = vacunacion[vacunacion['date'] == '29-01-2021']

total_vacunas = np.sum(vaccines['daily_vaccinations'])

print(f"El total de vacunas aplicadas el día 29/JAN/21 en todo el mundo fue de: {total_vacunas} ")
# Out:
# El total de vacunas aplicadas el día 29/JAN/21 en todo el mundo fue de: 4884052.0
# <ipython-input-68-be8a5d916c84>:3: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   vaccines = vacunacion[vacunacion['date'] == '29-01-2021']

# %%
#g
conDiferencias = vacunacion.assign(diferencias=vacunacion['daily_vaccinations'] - vacunacion['daily_vaccinations_raw'])
conDiferencias
# Out:
#            country iso_code       date  total_vaccinations  people_vaccinated  \
# 0      Afghanistan      AFG 2021-02-22                 0.0                0.0
# 1      Afghanistan      AFG 2021-02-23                 NaN                NaN
# 2      Afghanistan      AFG 2021-02-24                 NaN                NaN
# 3      Afghanistan      AFG 2021-02-25                 NaN                NaN
# 4      Afghanistan      AFG 2021-02-26                 NaN                NaN
# ...            ...      ...        ...                 ...                ...
# 86507     Zimbabwe      ZWE 2022-03-25           8691642.0          4814582.0
# 86508     Zimbabwe      ZWE 2022-03-26           8791728.0          4886242.0
# 86509     Zimbabwe      ZWE 2022-03-27           8845039.0          4918147.0
# 86510     Zimbabwe      ZWE 2022-03-28           8934360.0          4975433.0
# 86511     Zimbabwe      ZWE 2022-03-29           9039729.0          5053114.0
#
# ...

# %%
#h

print('primer reporte: ', vacunacion['date'].min())
print('último reporte: ', vacunacion['date'].max())

periodo = vacunacion['date'].max() - vacunacion['date'].min()

print("Los dias entre el primer reporte y el ultimo son:", periodo)
# Out:
# primer reporte:  2020-12-02 00:00:00
# último reporte:  2022-03-29 00:00:00
# Los dias entre el primer reporte y el ultimo son: 482 days 00:00:00

# %%
#i
conCantidad= vacunacion.copy()
conCantidad['countvac'] = conCantidad['vaccines'].str.split('/').str.len()
conCantidad
# Out:
#            country iso_code       date  total_vaccinations  people_vaccinated  \
# 0      Afghanistan      AFG 2021-02-22                 0.0                0.0
# 1      Afghanistan      AFG 2021-02-23                 NaN                NaN
# 2      Afghanistan      AFG 2021-02-24                 NaN                NaN
# 3      Afghanistan      AFG 2021-02-25                 NaN                NaN
# 4      Afghanistan      AFG 2021-02-26                 NaN                NaN
# ...            ...      ...        ...                 ...                ...
# 86507     Zimbabwe      ZWE 2022-03-25           8691642.0          4814582.0
# 86508     Zimbabwe      ZWE 2022-03-26           8791728.0          4886242.0
# 86509     Zimbabwe      ZWE 2022-03-27           8845039.0          4918147.0
# 86510     Zimbabwe      ZWE 2022-03-28           8934360.0          4975433.0
# 86511     Zimbabwe      ZWE 2022-03-29           9039729.0          5053114.0
#
# ...

# %%
# j
antes20 = vacunacion.loc[vacunacion['date'] < '20-12-2020']
antes20
# Out:
# <ipython-input-72-2476089cdfd9>:2: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   antes20 = vacunacion.loc[vacunacion['date'] < '20-12-2020']
#              country iso_code       date  total_vaccinations  \
# 13403         Canada      CAN 2020-12-14                 5.0
# 13404         Canada      CAN 2020-12-15               727.0
# 13405         Canada      CAN 2020-12-16              3025.0
# 13406         Canada      CAN 2020-12-17              7279.0
# 13407         Canada      CAN 2020-12-18             11296.0
# ...              ...      ...        ...                 ...
# 82362  United States      USA 2020-12-15             84638.0
# 82363  United States      USA 2020-12-16            244549.0
# 82364  United States      USA 2020-12-17            517161.0
# 82365  United States      USA 2020-12-18            933551.0
# ...

# %%
#l

with pd.ExcelWriter("resultadosReto.xlsx") as writer:
    conDiferencias.to_excel(writer, sheet_name="conDiferencias")
    conCantidad.to_excel(writer, sheet_name="conCantidad")
    antes20.to_excel(writer, sheet_name="antes20")
    pfizer.to_excel(writer, sheet_name="pfizer")
